# %%
# %pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.2 is available.
# You should consider upgrading via the 'c:\Users\mahdi\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

X,y = load_breast_cancer(as_frame=True, return_X_y=True)

# %%
df = pd.concat((X,y), axis=1)

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
df.isna().sum()
# Out:
# mean radius                0
# mean texture               0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
df.target.value_counts()
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
sns.displot(
    data=df,
    x='mean radius',
    hue='target',
    palette="Dark2"
)

# %%
df['radius error']=df['radius error']*10

# %%
g= sns.displot(
    data=df,
    x='radius error',
    hue='target',
    palette="Dark2"
)
g.figure.axes[0].set_xlim(1,5)
# Out:
# (1.0, 5.0)

# %%
df_mean = df.filter(regex='mean|target')

# %%
df_mean
# Out:
#      mean radius  mean texture  mean smoothness  mean compactness  \
# 0          17.99         10.38          0.11840           0.27760
# 1          20.57         17.77          0.08474           0.07864
# 2          19.69         21.25          0.10960           0.15990
# 3          11.42         20.38          0.14250           0.28390
# 4          20.29         14.34          0.10030           0.13280
# ..           ...           ...              ...               ...
# 564        21.56         22.39          0.11100           0.11590
# 565        20.13         28.25          0.09780           0.10340
# 566        16.60         28.08          0.08455           0.10230
# 567        20.60         29.33          0.11780           0.27700
# 568         7.76         24.54          0.05263           0.04362
#
#      mean concavity  mean concave points  mean symmetry  \
# 0           0.30010              0.14710         0.2419
# 1           0.08690              0.07017         0.1812
# ...

# %%
sns.heatmap(
    abs(df_mean.corr()),
    annot=True,
    cmap='Reds'
)
# Out:
# <Axes: >

# %%
df_error = df.filter(regex='error$', axis=1)

# %%
df_error
# Out:
#      radius error  texture error  smoothness error  compactness error  \
# 0          1.0950         0.9053          0.006399            0.04904
# 1          0.5435         0.7339          0.005225            0.01308
# 2          0.7456         0.7869          0.006150            0.04006
# 3          0.4956         1.1560          0.009110            0.07458
# 4          0.7572         0.7813          0.011490            0.02461
# ..            ...            ...               ...                ...
# 564        1.1760         1.2560          0.010300            0.02891
# 565        0.7655         2.4630          0.005769            0.02423
# 566        0.4564         1.0750          0.005903            0.03731
# 567        0.7260         1.5950          0.006522            0.06158
# 568        0.3857         1.4280          0.007189            0.00466
#
#      concavity error  concave points error  symmetry error  \
# 0            0.05373               0.01587         0.03003
# ...

# %%
sns.heatmap(
    abs(df_error.corr()),
    annot=True,
    cmap='Reds'
)
# Out:
# <Axes: >

# %%
df.drop(columns=['mean perimeter', 'mean area', 'worst perimeter', 'worst area', 'perimeter error', 'area error'], inplace=True)

# %%
df.shape
# Out:
# (569, 25)

# %%
sns.relplot(
    data=df,
    x='radius error',
    y='mean radius',
    palette="Dark2"
)
# Out:
# C:\Users\mahdi\AppData\Local\Temp\ipykernel_7712\1479656568.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.relplot(

# %%
g = sns.displot(
    data=df,
    x='mean radius',
    hue='target',
    palette="Dark2"
)
g.figure.axes[0].set_xlim(7,11)
# Out:
# (7.0, 11.0)

# %%
g = sns.displot(
    data=df,
    x='mean radius',
    hue='target',
    palette="Dark2"
)
g.figure.axes[0].set_xlim(14.60,30)
# Out:
# (14.6, 30.0)

# %%
sns.displot(
    data=df,
    x='mean texture',
    hue = 'target'
)

# %%
sns.relplot(
    data=df,
    x='mean texture',
    y='texture error',
    palette="Dark2"
)
# Out:
# C:\Users\mahdi\AppData\Local\Temp\ipykernel_7712\3215173351.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.relplot(

# %%
sns.displot(
    data=df,
    x='mean smoothness',
    hue='target',
    palette="Dark2"
)

# %%
sns.displot(
    data=df,
    x='worst smoothness',
    hue='target',
    palette="Dark2"
)

# %%
sns.relplot(
    data=df,
    x='mean smoothness',
    y='worst smoothness',
    palette="Dark2"
)
# Out:
# C:\Users\mahdi\AppData\Local\Temp\ipykernel_7712\968429674.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.relplot(

# %%
sns.displot(
    data=df,
    x='smoothness error',
    hue='target',
    palette="Dark2"
)

# %%
df['mean compactness']=df['mean compactness'] *20

# %%
g = sns.displot(
    data=df,
    x='mean compactness',
    hue='target',
    palette="Dark2"
)

# %%
g = sns.displot(
    data=df,
    x='mean concavity',
    hue='target',
    palette="Dark2"
)

# %%
g = sns.displot(
    data=df,
    x='mean concave points',
    hue='target',
    palette="Dark2"
)

# %%
g = sns.relplot(
    data=df,
    x='mean concave points',
    y='mean concavity',
    palette="Dark2"
)
# Out:
# C:\Users\mahdi\AppData\Local\Temp\ipykernel_7712\3626006049.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   g = sns.relplot(

# %%
sns.regplot(
    data=df,
    x='mean fractal dimension',
    y='target',
    logistic=True
    
)
# Out:
# <Axes: xlabel='mean fractal dimension', ylabel='target'>

# %%
df_worst = df.filter(regex='worst|target')

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import  r2_score

df=df.filter(regex='mean|worst|target')
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['target']),df.target, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

model = RandomForestRegressor()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)


r2 = r2_score(y_test, y_pred)
print(f'R2 Score : {r2}')
# Out:
# R2 Score : 0.8428681952178185

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import  r2_score

df=df.filter(regex='mean|worst|target')
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['target']),df.target, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)


r2 = r2_score(y_test, y_pred)
print(f'R2 Score : {r2}')
# Out:
# R2 Score : 0.6525381021884579

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# اگر y_pred احتمالات باشد:
y_pred_labels = (np.array(y_pred) > 0.5).astype(int)

# حالا متریک‌ها کار می‌کنند
y_pred = model.predict(X_test)
sns.heatmap(
    confusion_matrix(y_test, y_pred_labels),
    annot=True,
    cmap="Blues"
)

print(classification_report(y_test, y_pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        43
#            1       0.96      0.96      0.96        71
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
s = y_pred == y_test

s[s == False]
s
# Out:
# 204    True
# 70     True
# 131    True
# 431    True
# 540    True
#        ...
# 486    True
# 75     True
# 249    True
# 238    True
# 265    True
# Name: target, Length: 114, dtype: bool

# %%
df.mean()
# Out:
# mean radius               14.127292
# mean texture              19.289649
# mean smoothness            0.096360
# mean compactness           0.104341
# mean concavity             0.088799
# mean concave points        0.048919
# mean symmetry              0.181162
# mean fractal dimension     0.062798
# target                     0.627417
# dtype: float64

# %%
df_worst.mean()
# Out:
# worst radius               16.269190
# worst texture              25.677223
# worst smoothness            0.132369
# worst compactness           0.254265
# worst concavity             0.272188
# worst concave points        0.114606
# worst symmetry              0.290076
# worst fractal dimension     0.083946
# target                      0.627417
# dtype: float64

# %%
df_worst.iloc[90]
# Out:
# worst radius               16.11000
# worst texture              29.11000
# worst smoothness            0.11150
# worst compactness           0.17660
# worst concavity             0.09189
# worst concave points        0.06946
# worst symmetry              0.25220
# worst fractal dimension     0.07246
# target                      1.00000
# Name: 90, dtype: float64

# %%
df[df.target==0].mean()
# Out:
# mean radius               17.462830
# mean texture              21.604906
# mean smoothness            0.102898
# mean compactness           0.145188
# mean concavity             0.160775
# mean concave points        0.087990
# mean symmetry              0.192909
# mean fractal dimension     0.062680
# target                     0.000000
# dtype: float64

# %%
df[df.target==1].mean()
# Out:
# mean radius               12.146524
# mean texture              17.914762
# mean smoothness            0.092478
# mean compactness           0.080085
# mean concavity             0.046058
# mean concave points        0.025717
# mean symmetry              0.174186
# mean fractal dimension     0.062867
# target                     1.000000
# dtype: float64

# %%
g = sns.displot(
    data=df_worst,
    x='worst concavity',
    hue='target',
)
g.figure.axes[0].axvline(0.09, ls='--',color='blue')
g.figure.axes[0].axvline(0.16, ls='--',color='green')
g.figure.axes[0].axvline(0.45, ls='--',color='red')
